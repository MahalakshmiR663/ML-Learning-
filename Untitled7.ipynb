# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("C:\\Users\\USER\\Downloads\\data.csv")
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
le=LabelEncoder()

# %%
x=data
print(x.shape)
# Out:
# (569, 33)

# %%
y=data['diagnosis']
print(y.shape)
y.head()
# Out:
# (569,)
# 0    M
# 1    M
# 2    M
# 3    M
# 4    M
# Name: diagnosis, dtype: object

# %%
labels=le.fit_transform(data.diagnosis)

# %%
data['diagnosis']=labels

# %%
data.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data['diagnosis'].value_counts()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
ben=data[data.diagnosis==0]

# %%
print(len(ben))
# Out:
# 357

# %%
ben.head()
# Out:
#           id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 19   8510426          0       13.540         14.36           87.46      566.3
# 20   8510653          0       13.080         15.71           85.63      520.0
# 21   8510824          0        9.504         12.44           60.34      273.9
# 37    854941          0       13.030         18.42           82.61      523.8
# 46  85713702          0        8.196         16.84           51.71      201.9
#
#     smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 19          0.09779           0.08129         0.06664             0.047810
# 20          0.10750           0.12700         0.04568             0.031100
# 21          0.10240           0.06492         0.02956             0.020760
# 37          0.08983           0.03766         0.02562             0.029230
# 46          0.08600           0.05943         0.01588             0.005917
#
# ...

# %%
mal=data[data.diagnosis==1]
mal.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
print(len(mal))
# Out:
# 212

# %%
ben_sample=ben.sample(n=212)

# %%
print(len(ben))
# Out:
# 357

# %%
cdata=pd.concat([ben_sample,mal],axis=0)

# %%
cdata.shape
# Out:
# (424, 33)

# %%
cdata.tail()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 563  926125          1        20.92         25.09           143.0     1347.0
# 564  926424          1        21.56         22.39           142.0     1479.0
# 565  926682          1        20.13         28.25           131.2     1261.0
# 566  926954          1        16.60         28.08           108.3      858.1
# 567  927241          1        20.60         29.33           140.1     1265.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 563          0.10990            0.2236         0.31740              0.14740
# 564          0.11100            0.1159         0.24390              0.13890
# 565          0.09780            0.1034         0.14400              0.09791
# 566          0.08455            0.1023         0.09251              0.05302
# 567          0.11780            0.2770         0.35140              0.15200
#
# ...

# %%
cdata.head()
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 507  91544002          0       11.060         17.12           71.25
# 568     92751          0        7.760         24.54           47.92
# 459   9112712          0        9.755         28.20           61.68
# 158    871122          0       12.060         12.74           76.84
# 51     857373          0       13.640         16.34           87.21
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 507      366.5          0.11940           0.10710         0.04063
# 568      181.0          0.05263           0.04362         0.00000
# 459      290.9          0.07984           0.04626         0.01541
# 158      448.6          0.09311           0.05241         0.01972
# 51       571.8          0.07685           0.06059         0.01857
#
#      concave points_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 507              0.04268  ...          20.74            76.08       411.1
# ...

# %%
from sklearn.datasets import load_iris
iris=load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['target'].value_counts()
# Out:
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
x=df[df.target==0]
print(len(x))
# Out:
# 50

# %%
y=df[df.target==1]
print(len(y))
# Out:
# 50

# %%
z=df[df.target==2]
print(len(z))
# Out:
# 50
